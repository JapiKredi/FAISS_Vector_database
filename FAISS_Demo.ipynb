# %% [markdown]
# <a href="https://colab.research.google.com/github/JapiKredi/FAISS_Vector_database/blob/main/FAISS_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install langchain
# !pip install pypdf
# !pip install sentence-transformers==2.2.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 34.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 41.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.6 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# !pip install tiktoken
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 47.9 MB/s eta 0:00:00
# ...

# %%
# !mkdir pdfs

# %%
from langchain.document_loaders import PyPDFDirectoryLoader

# %%
loader = PyPDFDirectoryLoader("/content/pdfs")
data = loader.load()

# %%
data
# Out:
# [Document(page_content='Chapter 6. Money, Liquidity, Credit, and Debt \n \n \n Contents Page \nI.\xa0 Introduction .................................................................................................................. ..3\xa0\nA. Basic Functions of Money ........................................................................................4 \xa0\nB. Rationale for Compili ng a Money Aggregate ...........................................................4 \xa0\nII.\xa0 Broad Money .................................................................................................................4 \xa0\nA. Definition ................................................................................................................. .4\xa0\nB. Financial Instruments Included in Broad Money ......................................................5 \xa0\nC. Money-Issuing, Money Neutral,  and Money-Holding Sectors ...............................16 \xa0\nIII.\xa0Broad Money and Money Aggr
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
text_chunks = text_splitter.split_documents(data)

# %%
len(text_chunks)
# Out:
# 407

# %%
text_chunks[2]
# Out:
# Document(page_content='III.\xa0Broad Money and Money Aggregates .........................................................................19 \xa0\nA. Money Aggregates and Sub-Aggregates .................................................................19 \xa0\nB. Broad Money Counterparts or Sources ...................................................................23 \xa0\nIV.\xa0Monetary Base .............................................................................................................26', metadata={'source': '/content/pdfs/Money_supply.pdf', 'page': 0})

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
from langchain.vectorstores import FAISS

# %%
vectorstore=FAISS.from_documents(text_chunks, embeddings)

# %%
query = "What is m2 money supply?"

# %%
docs = vectorstore.similarity_search(query, k=3)

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('openai_key')

# %%
import os
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain.llms import OpenAI

# %%
llm = OpenAI()
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
from langchain.chains import RetrievalQA

# %%
qa = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=vectorstore.as_retriever())

# %%
query = "What is m2 money supply?"

# %%
print(qa.run(query))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
#  M2 money supply refers to the broader money aggregate that includes currency held by the public, demand deposits, time deposits, savings deposits, securities issued by ODCs, MMF shares, and the net position of securities used in repurchase agreement transactions. It is usually the second-ranked aggregate in a country's monetary system and measures the money available for making purchases of goods, services, and financial assets.

# %%
query2 = "What happens after m2 money supply declines?"

# %%
print(qa.run(query2))
# Out:
#  The effects of a decline in M2 money supply will depend on the specific reasons for the decline and the current economic conditions. In general, a decrease in M2 money supply could lead to higher interest rates and a decrease in consumer spending, which could have a negative impact on economic growth. However, it could also be a result of a decrease in demand for credit, which could indicate a stronger economy. Without more context, it is difficult to determine the exact consequences of a decline in M2 money supply.
